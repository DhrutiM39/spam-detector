# %%
# %run "c:/anaconda/spam detector project/spam_detector.py"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File C:\anaconda\spam detector project\spam_detector.py:19
#      15 # ──────────────────────────────────────────────────────────────
#      16 # IMPORTS
#      17 # ──────────────────────────────────────────────────────────────
#      18 import sys, io
# ---> 19 sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8', errors='replace')
#      21 from sklearn.linear_model import LogisticRegression
#      22 from sklearn.model_selection import train_test_split
#
# AttributeError: 'OutStream' object has no attribute 'buffer'
